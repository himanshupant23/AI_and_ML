# %% [markdown]
# ## pandas tutorial

# %%
import numpy as np
import pandas as pd

# %%
labels=["a","b","c"]
my_List=[10,20,30]
arr= np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_List)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# ##### dataframe

# %%
data= {
    "Name": ["john","Anna","Peter","Linda"],
    "Age":[28,34,29,42],
    "City":["new york","paris","berlin","london"],
    "Salary":[65000,7000,25000,50000]
}

# %%
 df=pd.DataFrame(data)

# %%
 df
# Out:
#     Name  Age      City  Salary
# 0   john   28  new york   65000
# 1   Anna   34     paris    7000
# 2  Peter   29    berlin   25000
# 3  Linda   42    london   50000

# %%
data_list=[
     ["john",34,"USA",80000],
    [ "Anna",28,"India",70000],
    [  "Peter",34,"new york", 25000],
      ["Linda",34,"Berlin", 50000]
]
df2=pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1         2      3
# 0   john  34       USA  80000
# 1   Anna  28     India  70000
# 2  Peter  34  new york  25000
# 3  Linda  34    Berlin  50000

# %%
columns=["Name","Age","City","Salary"]
df2=pd.DataFrame(data_list,columns=columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   34       USA   80000
# 1   Anna   28     India   70000
# 2  Peter   34  new york   25000
# 3  Linda   34    Berlin   50000

# %% [markdown]
# ##### selection and indexing of columns

# %%
df2["Name"]
# Out:
# 0     john
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df2["Age"]
# Out:
# 0    34
# 1    28
# 2    34
# 3    34
# Name: Age, dtype: int64

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   john       USA
# 1   Anna     India
# 2  Peter  new york
# 3  Linda    Berlin

# %% [markdown]
# #### Creating a new columns

# %%
df2["Designation"]=["doctor","engineer","doctor","engineer"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   john   34       USA   80000      doctor
# 1   Anna   28     India   70000    engineer
# 2  Peter   34  new york   25000      doctor
# 3  Linda   34    Berlin   50000    engineer

# %%
df2.drop("Designation",axis=1)
# Out:
#     Name  Age      City  Salary
# 0   john   34       USA   80000
# 1   Anna   28     India   70000
# 2  Peter   34  new york   25000
# 3  Linda   34    Berlin   50000

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   john   34       USA   80000      doctor
# 1   Anna   28     India   70000    engineer
# 2  Peter   34  new york   25000      doctor
# 3  Linda   34    Berlin   50000    engineer

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age      City  Salary Designation
# 1   Anna   28     India   70000    engineer
# 2  Peter   34  new york   25000      doctor
# 3  Linda   34    Berlin   50000    engineer

# %% [markdown]
# #### selecting rows

# %%
df2.loc[0]
# Out:
# Name             john
# Age                34
# City              USA
# Salary          80000
# Designation    doctor
# Name: 0, dtype: object

# %% [markdown]
# ##### selecting subsets of rows and columns

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#     City  Salary
# 0    USA   80000
# 1  India   70000

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   34
# 3  Linda   34

# %% [markdown]
# ##### conditional selections

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   john   34       USA   80000      doctor
# 1   Anna   28     India   70000    engineer
# 2  Peter   34  new york   25000      doctor
# 3  Linda   34    Berlin   50000    engineer

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age      City  Salary Designation
# 0   john   34       USA   80000      doctor
# 2  Peter   34  new york   25000      doctor
# 3  Linda   34    Berlin   50000    engineer

# %%
df2[(df2["Age"]>30 )& (df2["City"]== "USA")]
# Out:
#    Name  Age City  Salary Designation
# 0  john   34  USA   80000      doctor
